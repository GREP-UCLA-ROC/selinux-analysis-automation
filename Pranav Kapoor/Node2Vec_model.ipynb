# %%
# !pip install node2vec
# Out:
# Requirement already satisfied: node2vec in /usr/local/lib/python3.10/dist-packages (0.4.6)
# Requirement already satisfied: gensim<5.0.0,>=4.1.2 in /usr/local/lib/python3.10/dist-packages (from node2vec) (4.3.2)
# Requirement already satisfied: joblib<2.0.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from node2vec) (1.4.2)
# Requirement already satisfied: networkx<3.0,>=2.5 in /usr/local/lib/python3.10/dist-packages (from node2vec) (2.8.8)
# Requirement already satisfied: numpy<2.0.0,>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from node2vec) (1.25.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.55.1 in /usr/local/lib/python3.10/dist-packages (from node2vec) (4.66.4)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim<5.0.0,>=4.1.2->node2vec) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim<5.0.0,>=4.1.2->node2vec) (7.0.4)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim<5.0.0,>=4.1.2->node2vec) (1.14.1)

# %%
import pandas as pd
import networkx as nx

# Load SELinuxRealTE.csv
df_selinux = pd.read_csv('/content/Data/SELinuxRealTE.csv')

# Load attributes.csv
df_attributes = pd.read_csv('/content/Data/attributes.csv')

# Load objectclass.csv
df_objectclass = pd.read_csv('/content/Data/objectclass.csv')

# %%
# Create empty directed graph for SELinux policy
G_selinux = nx.DiGraph()

# Add edges from SELinuxRealTE.csv
for _, row in df_selinux.iterrows():
    source = row['Source']
    target = row['Target']
    obj_class = row['ObjectClass']
    permission = row['Permission']
    G_selinux.add_edge(source, target, object_class=obj_class, permission=permission)

# %%
# Create attribute graph
G_attributes = nx.Graph()

# Add nodes and edges from attributes.csv
for _, row in df_attributes.iterrows():
    context = row['1']
    attributes = row['2'].split(', ')
    G_attributes.add_node(context)
    for attr in attributes:
        G_attributes.add_edge(context, attr)

# %%
# Create objectclass graph
G_objectclass = nx.Graph()

# Add nodes and edges from objectclass.csv
for _, row in df_objectclass.iterrows():
    obj_class = row['Name']
    permissions = row['Permissions'].split(', ')
    G_objectclass.add_node(obj_class)
    for perm in permissions:
        G_objectclass.add_edge(obj_class, perm)

# %%
from node2vec import Node2Vec

# Convert SELinux policy graph to node2vec format
node2vec_selinux = Node2Vec(G_selinux, dimensions=64, walk_length=30, num_walks=200, workers=4)
# Out:
# Computing transition probabilities:   0%|          | 0/4721 [00:00<?, ?it/s]

# %%
# Embed nodes
model_selinux = node2vec_selinux.fit(window=10, min_count=1, batch_words=4)

# %%
# Get node embeddings
embeddings_selinux = {node: model_selinux.wv[node] for node in G_selinux.nodes}

# %%
# Similarly, apply node2vec to attribute and objectclass graphs
node2vec_attributes = Node2Vec(G_attributes, dimensions=64, walk_length=30, num_walks=200, workers=4)
model_attributes = node2vec_attributes.fit(window=10, min_count=1, batch_words=4)
embeddings_attributes = {node: model_attributes.wv[node] for node in G_attributes.nodes}

node2vec_objectclass = Node2Vec(G_objectclass, dimensions=64, walk_length=30, num_walks=200, workers=4)
model_objectclass = node2vec_objectclass.fit(window=10, min_count=1, batch_words=4)
embeddings_objectclass = {node: model_objectclass.wv[node] for node in G_objectclass.nodes}
# Out:
# Computing transition probabilities:   0%|          | 0/5234 [00:00<?, ?it/s]
# Computing transition probabilities:   0%|          | 0/410 [00:00<?, ?it/s]

# %%
from sklearn.ensemble import IsolationForest

# Convert embeddings to a format suitable for anomaly detection
X_selinux = [embeddings_selinux[node] for node in G_selinux.nodes]
X_attributes = [embeddings_attributes[node] for node in G_attributes.nodes]
X_objectclass = [embeddings_objectclass[node] for node in G_objectclass.nodes]

# %%
# Fit Isolation Forest for anomaly detection
detector_selinux = IsolationForest(contamination=0.1)
detector_selinux.fit(X_selinux)
anomalies_selinux = detector_selinux.predict(X_selinux)

detector_attributes = IsolationForest(contamination=0.1)
detector_attributes.fit(X_attributes)
anomalies_attributes = detector_attributes.predict(X_attributes)

detector_objectclass = IsolationForest(contamination=0.1)
detector_objectclass.fit(X_objectclass)
anomalies_objectclass = detector_objectclass.predict(X_objectclass)

# %%
# Print anomalies (nodes identified as anomalies)
print("Anomalies in SELinux Policy Graph:")
print([node for node, anomaly in zip(G_selinux.nodes, anomalies_selinux) if anomaly == -1])

print("Anomalies in Attribute Graph:")
print([node for node, anomaly in zip(G_attributes.nodes, anomalies_attributes) if anomaly == -1])

print("Anomalies in ObjectClass Graph:")
print([node for node, anomaly in zip(G_objectclass.nodes, anomalies_objectclass) if anomaly == -1])
# Out:
# Anomalies in SELinux Policy Graph:
# ['lib_t', 'var_lock_t', 'usr_t', 'antivirus_db_t', 'login_exec_t', 'file_type', 'httpd_log_t', 'var_yp_t', 'user_home_dir_t', 'spamass_milter_data_t', 'systemd_logind_var_run_t', 'virt_etc_t', 'var_lib_t', 'httpd_sys_content_t', 'glusterd_var_lib_t', 'sysctl_t', 'mozilla_exec_t', 'mysqld_etc_t', 'pingd_etc_t', 'telepathy_idle_tmp_t', 'kdump_t', 'install_exec_t', 'initrc_var_run_t', 'mock_build_exec_t', 'dhcpd_tmp_t', 'postfix_master_t', 'cyrus_var_lib_t', 'rsync_t', 'rsync_data_t', 'shell_exec_t', 'dhcp_etc_t', 'man_t', 'container_var_lib_t', 'sysctl_fs_t', 'NetworkManager_var_run_t', 'pppd_etc_rw_t', 'named_filetrans_domain', 'fonts_cache_t', 'afs_config_t', 'proc_t', 'cardmgr_var_run_t', 'ctdbd_tmp_t', 'pki_tomcat_t', 'rpm_var_cache_t', 'httpd_user_ra_content_t', 'neutron_initrc_exec_t', 'mock_var_lib_t', 'minidlna_t', 'xdm_var_run_t', 'mysqld_db_t', 'lvm_etc_t', 'mtrr_device_t', 'httpd_config_t', 'public_content_t', 'boltd_var_lib_t', 'systemd_passwd_var_run_t', 'apm_exec_t', 'cloud_init_exec_t', 'user_devpts_t', 'dcc_client_map_t', 'ld_so_t', 'tgtd_t', 'postgresql_tmp_t', 'cluster_conf_t', 'vmtools_unconfined_exec_t', 'postfix_public_t', 'kdumpctl_tmp_t', 'pam_var_console_t', 'screen_var_run_t', 'bluetooth_conf_t', 'httpd_user_content_t', 'systemd_systemctl_exec_t', 'plymouth_exec_t', 'ninfod_exec_t', 'avahi_exec_t', 'system_map_t', 'httpd_unit_file_t', 'zarafa_monitor_exec_t', 'root_t', 'kmod_exec_t', 'mailman_data_t', 'sambagui_exec_t', 'gitd_exec_t', 'qmail_spool_t', 'smokeping_cgi_rw_content_t', 'xferlog_t', 'modules_object_t', 'rpm_var_lib_t', 'courier_var_lib_t', 'qemu_exec_t', 'pulseaudio_exec_t', 'semanage_store_t', 'systemd_unit_file_t', 'postgresql_log_t', 'noxattrfs', 'dirsrvadmin_exec_t', 'hwdata_t', 'fusermount_exec_t', 'xserver_exec_t', 'locate_var_run_t', 'rhnsd_t', 'var_spool_t', 'modules_dep_t', 'hostname_exec_t', 'irc_exec_t', 'systemd_machined_var_run_t', 'snmpd_var_lib_t', 'proc_xen_t', 'rsync_exec_t', 'ld_so_cache_t', 'named_zone_t', 'svc_start_exec_t', 'named_conf_t', 'init_var_lib_t', 'polipo_exec_t', 'system_cronjob_var_lib_t', 'print_spool_t', 'krb5kdc_conf_t', 'svc_svc_t', 'sandbox_web_client_tmpfs_t', 'ricci_modservice_exec_t', 'gssproxy_var_lib_t', 'mnt_t', 'prelink_exec_t', 'avahi_var_run_t', 'named_cache_t', 'openshift_rw_file_t', 'telepathy_msn_exec_t', 'chroot_exec_t', 'mail_spool_t', 'fsadm_exec_t', 'setroubleshoot_tmpfs_t', 'collectd_script_tmp_t', 'plymouthd_spool_t', 'lastlog_t', 'squid_log_t', 'condor_var_lib_t', 'livecd_exec_t', 'brctl_exec_t', 'ldconfig_exec_t', 'ypxfr_exec_t', 'gconf_etc_t', 'dmidecode_exec_t', 'gpsd_tmpfs_t', 'screen_exec_t', 'canna_var_lib_t', 'xauth_exec_t', 'unconfined_munin_plugin_exec_t', 'dirsrv_var_log_t', 'zarafa_spooler_exec_t', 'varnishlog_exec_t', 'smsd_t', 'smsd_spool_t', 'xend_var_lib_t', 'crontab_exec_t', 'timemaster_tmpfs_t', 'admin_home_t', 'vdagent_var_run_t', 'zarafa_gateway_log_t', 'condor_startd_exec_t', 'initrc_tmp_t', 'motion_var_run_t', 'mailman_cgi_exec_t', 'virtlogd_var_run_t', 'portreserve_var_run_t', 'srvsvcd_exec_t', 'sshd_key_t', 'collectd_ra_content_t', 'power_unit_file_t', 'man2html_ra_content_t', 'mon_statd_var_run_t', 'man2html_rw_content_t', 'poly_t', 'etc_aliases_t', 'klogd_tmp_t', 'system_db_t', 'quota_db_t', 'webalizer_tmp_t', 'syslogd_initrc_exec_t', 'callweaver_exec_t', 'virt_var_lib_t', 'openct_var_run_t', 'dcc_client_tmp_t', 'syslogd_var_run_t', 'slapd_cert_t', 'radiusd_var_lib_t', 'gkeyringd_exec_t', 'fenced_exec_t', 'bitlbee_log_t', 'ipsec_conf_file_t', 'httpd_exec_t', 'rpm_script_tmp_t', 'nsd_conf_t', 'alsa_etc_rw_t', 'boltd_var_run_t', 'etc_runtime_t', 'squid_rw_content_t', 'dlm_controld_exec_t', 'policykit_resolve_exec_t', 'openshift_tmp_t', 'cupsd_var_run_t', 'mozilla_plugin_rw_t', 'wdmd_var_run_t', 'irqbalance_exec_t', 'psad_var_log_t', 'tetex_data_t', 'pegasus_openlmi_unconfined_exec_t', 'ssh_agent_tmp_t', 'geoclue_exec_t', 'varnishd_var_lib_t', 'man_cache_t', 'debuginfo_exec_t', 'dccm_tmp_t', 'kismet_var_run_t', 'por ...
# Anomalies in Attribute Graph:
# ['init_script_file_type', 'initrc_transition_domain', 'system_bus_type', 'systemprocess', 'userdom_home_reader_certs_type', 'abrt_domain', 'can_change_object_identity', 'abrt_handle_event_t', 'spoolfile', 'can_dump_kernel', 'can_receive_kernel_messages', 'memory_raw_read', 'user_tmp_type', 'crontab_domain', 'userdom_home_reader_type', 'mountpoint', 'polyparent', 'unreserved_port_type', 'afs_bosserver_t', 'afs_domain', 'afs_ptserver_t', 'afs_vlserver_t', 'reserved_port_type', 'rpc_port_type', 'agp_device_t', 'device_node', 'ajaxterm_devpts_t', 'ptynode', 'user_home_type', 'lockfile', 'tmpfsfile', 'fixed_disk_raw_read', 'scsi_generic_write', 'prelink_object', 'filesystem_type', 'antivirus_domain', 'httpd_content_type', 'httpd_script_exec_type', 'httpd_script_type', 'mailcontent_type', 'apm_bios_t', 'daemonrundir', 'audit_spool_t', 'security_file_type', 'privfd', 'screen_domain', 'auditadm_su_t', 'su_domain_type', 'can_change_process_role', 'can_system_change', 'sudodomain', 'userdom_home_manager_type', 'confined_admindomain', 'process_user_target', 'userdomain', 'autofs_device_t', 'noxattrfs', 'avahi_var_run_t', 'init_sock_file_type', 'bdev_t', 'base_file_type', 'base_ro_file_type', 'bluetooth_helper_input_xevent_t', 'input_xevent_type', 'xevent_type', 'xcolormap_type', 'xdrawable_type', 'bluetooth_helper_xproperty_t', 'xproperty_type', 'boinc_domain', 'systemd_mount_directory', 'fixed_disk_raw_write', 'bsdpty_device_t', 'gnome_home_type', 'cachefiles_device_t', 'cert_type', 'certmaster_port_t', 'ephemeral_port_type', 'cfengine_domain', 'chrome_sandbox_input_xevent_t', 'chrome_sandbox_xproperty_t', 'chroot_user_t', 'can_change_process_identity', 'ssh_dyntransition_domain', 'unconfined_login_domain', 'cinder_domain', 'client_xevent_t', 'clipboard_xproperty_t', 'clipboard_xselection_t', 'xselection_type', 'clock_device_t', 'cloudform_domain', 'cluster_port_t', 'cluster_domain', 'initrc_domain', 'virsh_transition_domain', 'cluster_tmpfs', 'cluster_log', 'cluster_pid', 'cockpit_session_t', 'login_pgm', 'polydomain', 'memory_raw_write', 'scsi_generic_read', 'comsat_port_t', 'condor_domain', 'configfs_t', 'console_device_t', 'consolekit_input_xevent_t', 'consolekit_xproperty_t', 'container_devpts_t', 'svirt_file_type', 'container_init_t', 'container_domain', 'container_net_domain', 'mcs_constrained_type', 'container_logreader_t', 'container_port_t', 'container_runtime_domain', 'container_t', 'sandbox_net_domain', 'svirt_sandbox_domain', 'container_userns_t', 'courier_domain', 'mta_exec_type', 'cpu_device_t', 'cpucontrol_domain', 'cpusetfs_t', 'crash_device_t', 'crond_tmp_t', 'cronjob_t', 'cron_job_domain', 'crypt_device_t', 'cups_pdf_t', 'cups_domain', 'systemd_private_tmp_type', 'sepgsql_admin_type', 'likewise_domains', 'device_t', 'devtty_t', 'dhcpc_port_t', 'disk_munin_plugin_t', 'munin_plugin_domain', 'milter_data_type', 'milter_domains', 'dlm_control_device_t', 'dovecot_domain', 'mailserver_delivery', 'dri_device_t', 'sepgsql_client_type', 'ecryptfs_device_t', 'efs_port_t', 'ephemeral_port_t', 'etc_runtime_t', 'etc_t', 'event_device_t', 'exim_t', 'mailserver_domain', 'mta_user_agent', 'fixed_disk_device_t', 'framebuf_device_t', 'freeipmi_domain', 'freeipmi_pid', 'freeipmi_ipmiseld_t', 'fs_t', 'fuse_device_t', 'futexfs_t', 'games_devpts_t', 'games_input_xevent_t', 'games_xproperty_t', 'gnomedomain', 'gdomap_port_t', 'git_daemon', 'glance_domain', 'gpfs_device_t', 'gpg_pinentry_input_xevent_t', 'pulseaudio_client', 'gpg_pinentry_tmpfs_t', 'pulseaudio_tmpfsfile', 'gpg_pinentry_xproperty_t', 'gpio_device_t', 'rpc_domain', 'guest_t', 'guest_usertype', 'login_userdomain', 'unpriv_userdomain', 'hadoop_datanode_port_t', 'hi_reserved_port_t', 'hplip_port_t', 'hsa_device_t', 'httpd_bool_t', 'base_typeattr_14', 'boolean_type', 'httpd_php_t', 'httpdcontent', 'httpd_sys_rw_content_t', 'httpd_user_content_t', 'httpd_user_content_type', 'httpd_user_htaccess_t', 'httpd_user_ra_content_t', 'httpd_user_rw_content_t', 'httpd_user_script_exec_t', 'h ...
# Anomalies in ObjectClass Graph:
# ['polmatch', 'binder', 'call', ' impersonate', ' set_context_mgr', ' transfer', 'bpf', 'map_create', ' map_read', ' map_write', ' prog_load', ' prog_run', 'cap2_userns', ' epolwakeup', 'context', 'contains', ' translate', 'access', 'acquire_svc', 'fd', 'use', 'infiniband_pkey', 'kernel_service', 'create_files_as', ' use_as_override', 'memprotect', 'mmap_zero', 'passwd', 'peer', 'recv', 'process2', 'nnp_transition', ' nosuid_transition', 'proxy', 'read', ' attach_queue', 'x_application_data', 'copy', ' paste', ' paste_after_confirm', 'query']

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Visualization function without labeling the nodes
def visualize_graph_with_anomalies_no_labels(G, anomalies, title):
    pos = nx.spring_layout(G)
    anomaly_nodes = [node for node, anomaly in zip(G.nodes, anomalies) if anomaly == -1]
    normal_nodes = [node for node, anomaly in zip(G.nodes, anomalies) if anomaly != -1]
    nx.draw_networkx_nodes(G, pos, nodelist=normal_nodes, node_color='green', node_size=50, label='Normal')
    nx.draw_networkx_nodes(G, pos, nodelist=anomaly_nodes, node_color='red', node_size=100, label='Anomaly')
    nx.draw_networkx_edges(G, pos, alpha=0.5)
    plt.title(title)
    plt.legend()
    plt.show()

# Visualize anomalies in SELinux Policy Graph
visualize_graph_with_anomalies_no_labels(G_selinux, anomalies_selinux, 'SELinux Policy Graph with Anomalies')

# Visualize anomalies in Attribute Graph
visualize_graph_with_anomalies_no_labels(G_attributes, anomalies_attributes, 'Attribute Graph with Anomalies')

# Visualize anomalies in ObjectClass Graph
visualize_graph_with_anomalies_no_labels(G_objectclass, anomalies_objectclass, 'ObjectClass Graph with Anomalies')
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# def visualize_graph_with_anomalies_no_labels(G, anomalies, title):
#     pos = nx.kamada_kawai_layout(G)  # Use Kamada-Kawai layout
#     anomaly_nodes = [node for node, anomaly in zip(G.nodes, anomalies) if anomaly == -1]
#     normal_nodes = [node for node, anomaly in zip(G.nodes, anomalies) if anomaly != -1]
#     nx.draw_networkx_nodes(G, pos, nodelist=normal_nodes, node_color='green', node_size=50, label='Normal')
#     nx.draw_networkx_nodes(G, pos, nodelist=anomaly_nodes, node_color='red', node_size=100, label='Anomaly')
#     nx.draw_networkx_edges(G, pos, alpha=0.5)
#     plt.title(title)
#     plt.legend()
#     plt.show()

# # Visualize anomalies in SELinux Policy Graph
# visualize_graph_with_anomalies_no_labels(G_selinux, anomalies_selinux, 'SELinux Policy Graph with Anomalies')

# # Visualize anomalies in Attribute Graph
# visualize_graph_with_anomalies_no_labels(G_attributes, anomalies_attributes, 'Attribute Graph with Anomalies')

# # Visualize anomalies in ObjectClass Graph
# visualize_graph_with_anomalies_no_labels(G_objectclass, anomalies_objectclass, 'ObjectClass Graph with Anomalies')
